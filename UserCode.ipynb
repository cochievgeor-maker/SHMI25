# %% [markdown]
# <a href="https://colab.research.google.com/github/cochievgeor-maker/SHMI25/blob/main/UserCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Тут просто нужно один раз прожать "Shift" + "Enter"

# %%
# !pip install rdkit
# !apt-get install xtb
# !pip install diffusers transformers accelerate torch --quiet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 47.0 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package xtb

# %%
# Клонируем весь репозиторий
# !git clone https://github.com/cochievgeor-maker/SHMI25.git

# Переходим в папку репозитория
# %cd SHMI25
import sys
sys.path.append('/content/SHMI25')

# %%
import AllForGit18
from AllForGit18 import run_calculation_interactive
from AllForGit18 import gap_to_wavenumber_and_color
from AllForGit18 import display_single_color, main_interface, quick_color_restore

# %% [markdown]
# ## Сперва мы сгенерируем изображение используя генеративную нейросеть! Запустите этот код и он дальше расскажет как с ним работать)

# %%
main_interface()
# Out:
# 🚀 Загрузка: DreamShaper (УНИВЕРСАЛЬНАЯ)
# 📁 Модель: lykon/dreamshaper-8
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# vocab.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/520 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Это команда для рассчета перехода. Тут вам будет предложенно написать папку для сохранения результата. Рекомендуется написать: "/content/SHMI25/output/" + название молекулы. Результат вы увидите в соответствующей папке)

# %%
run_calculation_interactive()
# Out:
# ...
# xTB Calculation from SMILES
# ...
# ✓ xTB is already installed
# Enter SMILES string (e.g., CCO for ethanol): CCO
#
# Available calculation types:
#   sp   - Single-point energy
#   opt  - Geometry optimization
#   freq - Frequency calculation
# Choose calculation type [sp/opt/freq] (default: sp): sp
# Molecular charge (default: 0): 0
# Spin multiplicity (default: 1): 1
# Solvent for GBSA model (e.g., water, methanol) [optional]: water
# Output directory (default: './output'): /content/SHMI25/output
# ✓ xTB is already installed
# Processing SMILES: CCO
# Generating 3D coordinates...
# Performing MMFF94 optimization...
# Saved geometry to: /content/SHMI25/output/CCO.xyz
# Saved molecule image to: /content/SHMI25/output/CCO.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# Running single-point energy calculation...
# Command: xtb CCO.xyz --sp --chrg 0 --uhf 0 --gbsa water
# ✓ Single-point calculation completed!
# Output saved to: single_point.log
#
# ...
# CALCULATION RESULTS
# ...

# %% [markdown]
# ## Дальше в аргумент функции "gap_to_wavenumber_and_color" нужно передать значение "homo_lumo_gap_hartree", которое вы увидите в результате выполнения предыдущего кода

# %%
res = gap_to_wavenumber_and_color( 0.4623602440750381)
display_single_color(res['rgb_color'])
# Out:
# Твой RGB вектор - (75, 0, 130)

# %% [markdown]
# ## А красить тут
# ранее вы получали RGB вектора - теперь их значения нужно записать в словари. Оформление 3 разных цветов смотрите в переменной "example"

# %%
# example = [
#     {'rgb': (255, 0, 0)},
#     {'rgb': (80, 50, 150)},
#     {'rgb': (0, 0, 255)}
# ]
colors_to_restore =[
    {'rgb': (80, 80, 0)},
    {'rgb': (80, 50, 150)},
    {'rgb': (0, 0, 255)}
]
result = quick_color_restore('/content/SHMI25/'+"NoMatchMorosi.png", colors_to_restore) # Первый аргумент функции - путь к вашей картинке

# %%
result # Запусти для отображения результата
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
result.save("quick_restore_result.png") # Тут можно сохранить ваши успехи по расскраске
